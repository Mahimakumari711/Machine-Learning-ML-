# %%
import pandas as pd
df=pd.read_csv(r"weather.csv")
print(df)
type(df)
# Out:
#         day  temperature  windspeed  humidity  event
# 0  1/1/2017           32          6        20   Rain
# 1  1/2/2017           35          7        30  Sunny
# 2  1/3/2017           28          2        45   Snow
# 3  1/4/2017           24          7        40   Snow
# 4  1/5/2017           32          4        35   Rain
# 5  1/6/2017           31          2        20  Sunny
# pandas.core.frame.DataFrame

# %%
weather_data=[['1/1/2017',32,6,20,'Rain'],
              ['1/2/2017', 35,7 ,30 ,'Sunny']  ,
             ['1/3/2017', 28,2,45, 'Snow'],
             ['1/4/2017',24 ,7,40  , 'Snow'],
             ['1/5/2017',32,4, 35 ,  'Rain'],
             ['1/6/2017',31,2, 20 ,'Sunny']
             ]
df1=pd.DataFrame(weather_data,columns=['day','temperature','windspeed'  ,'humidity'  ,'event'])
df1
# Out:
#         day  temperature  windspeed  humidity  event
# 0  1/1/2017           32          6        20   Rain
# 1  1/2/2017           35          7        30  Sunny
# 2  1/3/2017           28          2        45   Snow
# 3  1/4/2017           24          7        40   Snow
# 4  1/5/2017           32          4        35   Rain
# 5  1/6/2017           31          2        20  Sunny

# %% [markdown]
# ## Working on Rows and Columns

# %% [markdown]
# ### to get the shape of the table/database

# %%
print(df.shape)
# Out:
# (6, 5)

# %%
print(df.columns)
# Out:
# Index(['day', 'temperature', 'windspeed', 'humidity', 'event'], dtype='object')

# %%
df.head()  #displays first 5
# Out:
#         day  temperature  windspeed  humidity  event
# 0  1/1/2017           32          6        20   Rain
# 1  1/2/2017           35          7        30  Sunny
# 2  1/3/2017           28          2        45   Snow
# 3  1/4/2017           24          7        40   Snow
# 4  1/5/2017           32          4        35   Rain

# %%
df.head(3) #displays first 3
# Out:
#         day  temperature  windspeed  humidity  event
# 0  1/1/2017           32          6        20   Rain
# 1  1/2/2017           35          7        30  Sunny
# 2  1/3/2017           28          2        45   Snow

# %%
df.tail() #displays last 5
# Out:
#         day  temperature  windspeed  humidity  event
# 1  1/2/2017           35          7        30  Sunny
# 2  1/3/2017           28          2        45   Snow
# 3  1/4/2017           24          7        40   Snow
# 4  1/5/2017           32          4        35   Rain
# 5  1/6/2017           31          2        20  Sunny

# %%
df.tail(2) #display last 2
# Out:
#         day  temperature  windspeed  humidity  event
# 4  1/5/2017           32          4        35   Rain
# 5  1/6/2017           31          2        20  Sunny

# %%
df.sample() #random 1 sample
# Out:
#         day  temperature  windspeed  humidity event
# 0  1/1/2017           32          6        20  Rain

# %%
df.sample(2) #random 2 sample
# Out:
#         day  temperature  windspeed  humidity event
# 2  1/3/2017           28          2        45  Snow
# 3  1/4/2017           24          7        40  Snow

# %%
df.day #display a particular column
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df['day'] #display a particular column
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df[['day']] #display a particular column where double [] is for multiple values/columns
# Out:
#         day
# 0  1/1/2017
# 1  1/2/2017
# 2  1/3/2017
# 3  1/4/2017
# 4  1/5/2017
# 5  1/6/2017

# %%
df[['day','event']]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %%
df['temperature']
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
df.temperature.describe() #describes a  particuar column
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: temperature, dtype: float64

# %%
df.event.describe()
# Out:
# count        6
# unique       3
# top       Rain
# freq         2
# Name: event, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   humidity     6 non-null      int64
#  4   event        6 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 368.0+ bytes

# %%
df.iloc[2,4] #position based indexing
# Out:
# 'Snow'

# %%
df.loc[2,'event'] #label based indexing
# Out:
# 'Snow'

# %%
df.loc[2,'humidity']
# Out:
# 45

# %% [markdown]
# ## Minimal Operations

# %%
print(max(df.temperature)) #prints max temp
# Out:
# 35

# %%
df['temperature'].max()
# Out:
# 35

# %%
print(min(df.temperature)) #prints min temp
# Out:
# 24

# %%
df['temperature'].min()
# Out:
# 24

# %%
df['temperature'].std() #standard deviation
# Out:
# 3.8297084310253524

# %%
df.temperature.mean() #mean
# Out:
# 30.333333333333332

# %%
df.temperature  == df.temperature.max()  #comparision in terms of true and false  with the maximum value
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: temperature, dtype: bool

# %%
df.temperature  == df.temperature.min()  #comparision in terms of true and false  with the minimum value
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: temperature, dtype: bool

# %%
df[df.temperature  == df.temperature.max() ] #select rows which has max temp
# Out:
#         day  temperature  windspeed  humidity  event
# 1  1/2/2017           35          7        30  Sunny

# %%
df.day[df.temperature  == df.temperature.max() ]  #select only day column which has max temp
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df.index #starting ad ending oins
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df
# Out:
#         day  temperature  windspeed  humidity  event
# 0  1/1/2017           32          6        20   Rain
# 1  1/2/2017           35          7        30  Sunny
# 2  1/3/2017           28          2        45   Snow
# 3  1/4/2017           24          7        40   Snow
# 4  1/5/2017           32          4        35   Rain
# 5  1/6/2017           31          2        20  Sunny

# %%
df.set_index('day') #doesnt modify the original data frame
# Out:
#           temperature  windspeed  humidity  event
# day
# 1/1/2017           32          6        20   Rain
# 1/2/2017           35          7        30  Sunny
# 1/3/2017           28          2        45   Snow
# 1/4/2017           24          7        40   Snow
# 1/5/2017           32          4        35   Rain
# 1/6/2017           31          2        20  Sunny

# %%
df.set_index('day',inplace=True)  #mdify the original data frame

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         day  temperature  windspeed  humidity  event
# 0  1/1/2017           32          6        20   Rain
# 1  1/2/2017           35          7        30  Sunny
# 2  1/3/2017           28          2        45   Snow
# 3  1/4/2017           24          7        40   Snow
# 4  1/5/2017           32          4        35   Rain
# 5  1/6/2017           31          2        20  Sunny

# %%
df.sort_values(['windspeed']) #sort the values in ascending values
# Out:
#         day  temperature  windspeed  humidity  event
# 2  1/3/2017           28          2        45   Snow
# 5  1/6/2017           31          2        20  Sunny
# 4  1/5/2017           32          4        35   Rain
# 0  1/1/2017           32          6        20   Rain
# 1  1/2/2017           35          7        30  Sunny
# 3  1/4/2017           24          7        40   Snow

# %%
df.sort_values(['windspeed'],ascending=False)
# Out:
#         day  temperature  windspeed  humidity  event
# 1  1/2/2017           35          7        30  Sunny
# 3  1/4/2017           24          7        40   Snow
# 0  1/1/2017           32          6        20   Rain
# 4  1/5/2017           32          4        35   Rain
# 2  1/3/2017           28          2        45   Snow
# 5  1/6/2017           31          2        20  Sunny
